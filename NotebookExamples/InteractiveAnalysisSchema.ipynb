# %%
import analysis_schema
# Out:
# schema <class 'analysis_schema.SchemaModel.ytModel'>

# %%
model = analysis_schema.ytModel(Plot=[
                         {
                            "SlicePlot": {
                                "Dataset": {
                                    "FileName": "../yt_JSON_Schema/IsolatedGalaxy/galaxy0030/galaxy0030",
                                    "DatasetName": "IG"
                                },
                                "Axis":"x",
                                "FieldName": {
                                       "field": "density"
                                   }
                                   
                               }
                            }
                        ]
                    )

# %%
model.json()
# Out:
# '{"Data": null, "Plot": [{"SlicePlot": {"ds": {"fn": "../yt_JSON_Schema/IsolatedGalaxy/galaxy0030/galaxy0030", "DatasetName": "IG", "comments": null}, "FieldName": {"field": "density", "comments": null}, "axis": "x", "center": null, "width": null, "data_source": null, "Comments": null}, "ProjectionPlot": null, "PhasePlot": null}]}'

# %%
analysis_schema.BaseModelFunctions.show_plots(schema=model, display_inline=True)
# Out:
# /Users/swalkow2/anaconda3/lib/python3.7/site-packages/yt/utilities/logger.py:4: VisibleDeprecationWarning: The configuration file /Users/swalkow2/.config/yt/ytrc is deprecated in favor of /Users/swalkow2/.config/yt/yt.toml. Currently, both are present. Please manually remove the deprecated one to silence this warning.
# Deprecated since v4.0.0. This feature will be removed in v4.1.0
#   from yt.config import ytcfg
# yt : [INFO     ] 2021-09-16 11:33:00,592 Parameters: current_time              = 0.0060000200028298
# yt : [INFO     ] 2021-09-16 11:33:00,593 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2021-09-16 11:33:00,594 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-09-16 11:33:00,595 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2021-09-16 11:33:00,595 Parameters: cosmological_simulation   = 0
# SlicePlot
# found name: SlicePlot
# pulled func <function SlicePlot at 0x116553ea0> <class 'function'>
# ...
